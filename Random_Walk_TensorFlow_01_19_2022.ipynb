069999999999979, 11.079999999999979, 10.089999999999979, 11.099999999999978, 10.109999999999978, 11.119999999999978, 12.129999999999978, 13.139999999999977, 14.149999999999977, 15.159999999999977, 16.169999999999977, 17.17999999999998, 16.18999999999998, 15.19999999999998, 14.20999999999998, 13.21999999999998, 12.229999999999979, 13.239999999999979, 14.249999999999979, 13.259999999999978, 14.269999999999978, 15.279999999999978, 16.289999999999978, 15.299999999999978, 16.309999999999977, 15.319999999999977, 16.329999999999977, 15.339999999999977, 14.349999999999977, 15.359999999999976, 16.369999999999976, 17.379999999999978, 16.38999999999998, 15.399999999999979, 16.40999999999998, 15.419999999999979, 14.429999999999978, 13.439999999999978, 14.449999999999978, 13.459999999999978, 12.469999999999978, 11.479999999999977, 10.489999999999977, 11.499999999999977, 12.509999999999977, 13.519999999999976, 12.529999999999976, 13.539999999999976, 12.549999999999976, 13.559999999999976, 14.569999999999975, 15.579999999999975, 14.589999999999975, 13.599999999999975, 12.609999999999975, 11.619999999999974, 12.629999999999974, 11.639999999999974, 12.649999999999974, 11.659999999999973, 10.669999999999973, 9.679999999999973, 10.689999999999973, 9.699999999999973, 10.709999999999972, 9.719999999999972, 10.729999999999972, 9.739999999999972, 10.749999999999972, 9.759999999999971, 10.769999999999971, 9.779999999999971, 10.78999999999997, 9.79999999999997, 8.80999999999997, 9.81999999999997, 10.82999999999997, 11.83999999999997, 12.84999999999997, 11.85999999999997, 12.869999999999969, 13.879999999999969, 12.889999999999969, 13.899999999999968, 14.909999999999968, 13.919999999999968, 12.929999999999968, 13.939999999999968, 12.949999999999967, 11.959999999999967, 12.969999999999967, 11.979999999999967, 12.989999999999966, 11.999999999999966, 11.009999999999966, 10.019999999999966, 9.029999999999966, 10.039999999999965, 9.049999999999965, 8.059999999999965, 9.069999999999965, 8.079999999999965, 9.089999999999964, 8.099999999999964, 9.109999999999964, ...

# %% [markdown]
# # 1-Dimensional Random Walk With Force using B Constant (1, 5, 10)

# %%
N = 1000
u = 2*randint(0,2,size=N)-1
xs = cumsum(u)
plot(xs), xlabel('N'),ylabel('x(N)')
# Out:
# ([<matplotlib.lines.Line2D at 0x7f8c10688610>],
#  Text(0.5, 0, 'N'),
#  Text(0, 0.5, 'x(N)'))

# %%
N = 1000
u = 2*randint(0,2,size=N*2)-1
xs = cumsum(u)
x = np.linspace(-N, N, N*2)
y = xs
plot(x,y), xlabel('N'),ylabel('x(N)')
# Out:
# ([<matplotlib.lines.Line2D at 0x7f8c0fec2850>],
#  Text(0.5, 0, 'N'),
#  Text(0, 0.5, 'x(N)'))

# %%
xc = 1
B = 1
N = 60
u = 2*randint(0,2,size=N*2 + 1)-1
# xs = cumsum(u)
xf = list(range(-N, N + 1))
xa = np.zeros(N*2 + 1)

print(len(u), len(xa), len(xf))

for i in range(len(xf)):
    xa[i] =   ( u[i] + \
               ( -(B * ((xf[i] + xc) * (xf[i] + xc)) - (B *xf[i] * xf[i])) / xc))

xs = cumsum(xa)

x = np.linspace(-N, N, N*2 + 1)
y = xs
plot(x,y), xlabel('N'),ylabel('x(N)')
# Out:
# 121 121 121
# ([<matplotlib.lines.Line2D at 0x7f8c0b8501d0>],
#  Text(0.5, 0, 'N'),
#  Text(0, 0.5, 'x(N)'))

# %%
xc = 1
B = 5
N = 60
u = 2*randint(0,2,size=N*2 + 1)-1
# xs = cumsum(u)
xf = list(range(-N, N + 1))
xa = np.zeros(N*2 + 1)

print(len(u), len(xa), len(xf))

for i in range(len(xf)):
    xa[i] =   ( u[i] + \
               ( -(B * ((xf[i] + xc) * (xf[i] + xc)) - (B *xf[i] * xf[i])) / xc))

xs = cumsum(xa)

x = np.linspace(-N, N, N*2 + 1)
y = xs
plot(x,y), xlabel('N'),ylabel('x(N)')
# Out:
# 121 121 121
# ([<matplotlib.lines.Line2D at 0x7f8c0b7b9f10>],
#  Text(0.5, 0, 'N'),
#  Text(0, 0.5, 'x(N)'))

# %%
xc = 1
B = 10
N = 60
u = 2*randint(0,2,size=N*2 + 1)-1
# xs = cumsum(u)
xf = list(range(-N, N + 1))
xa = np.zeros(N*2 + 1)

print(len(u), len(xa), len(xf))

for i in range(len(xf)):
    xa[i] =   ( u[i] + \
               ( -(B * ((xf[i] + xc) * (xf[i] + xc)) - (B *xf[i] * xf[i])) / xc))

xs = cumsum(xa)

x = np.linspace(-N, N, N*2 + 1)
y = xs
plot(x,y), xlabel('N'),ylabel('x(N)')
# Out:
# 121 121 121
# ([<matplotlib.lines.Line2D at 0x7f8c0b7addd0>],
#  Text(0.5, 0, 'N'),
#  Text(0, 0.5, 'x(N)'))

# %%
import numpy as np
np.set_printoptions(threshold=np.inf)

Nvalues = [10,50,100,200,400]

for N in [10,50,100,200,400]:
    nsample = int(1000000/N)
    x = zeros(nsample)
    for i in range(nsample):
        z = randint(3,size=N)-1
        x[i] = sum(z)
plot(x)

# %%
# https://persagen.com/files/misc/random_walks-diffusion.pdf
# Random walk in one dimension - measurement
from pylab import *
N = 100
nsample = int(10000000/N)
x = zeros(nsample)
for i in range(nsample):
    z = 2*randint(0,2,size=N)-1
    x[i] = sum(z)
edges = array(range(-N,N+1))-0.5
Nx,e = histogram(x,edges)
x = (edges[:-1]+edges[1:])/2.0
dx = diff(edges)
Px = Nx/(dx*nsample)
plot(x,Px), xlabel('x'), ylabel('P(x)')
show()

# %%
# https://persagen.com/files/misc/random_walks-diffusion.pdf
# Random walk in one dimension - scaling
from pylab import *

Nvalues = [10,50,100,200,400]

for N in [10,50,100,200,400]:
    nsample = int(1000000/N)
    x = zeros(nsample)
    for i in range(nsample):
        z = randint(3,size=N)-1
        x[i] = sum(z)
    edges = array(range(-N,N+1))-0.5
    Nx,e = histogram(x,edges)
    x = (edges[:-1]+edges[1:])/2.0
    dx = diff(edges)
    Px = Nx/(dx*nsample)
    plot(x,Px)
show()

# %% [markdown]
# # 2-Dimensional Random Walk

# %% [markdown]
# ## 1,000 Walkers, 10 Steps

# %%
# defining the number of walkers
w = 1000
# defining the number of steps
s = 10
 
#creating two array for containing x and y coordinate
#of size equals to the number of walkers and filled up with 0's
x = np.zeros(w)
y = np.zeros(w)

for walkers in range(w):
    for steps in range(s):
        rand = randint(0,3)
        if rand == 0:
            y[walkers] = y[walkers] + 1
            x[walkers] = x[walkers]
        elif rand == 1:
            x[walkers] = x[walkers] + 1
            y[walkers] = y[walkers]
        elif rand == 2:
            y[walkers] = y[walkers] - 1
            x[walkers] = x[walkers]
        else:
            x[walkers] = x[walkers] - 1
            y[walkers] = y[walkers]
 
plt.scatter(x, y)
plt.grid()
plt.show()

# %% [markdown]
# ## 1,000 Walkers, 10 Steps + Weight (A)

# %%
# defining the number of walkers
w = 1000
# defining the number of steps
s = 10

A = .5
 
#creating two array for containing x and y coordinate
#of size equals to the number of walkers and filled up with 0's
x = np.zeros(w)
y = np.zeros(w)

for walkers in range(w):
    for steps in range(s):
        rand = randint(0,3)
        if rand == 0:
            y[walkers] = y[walkers] + 1
            x[walkers] = x[walkers] + A
        elif rand == 1:
            x[walkers] = x[walkers] + 1 + A
            y[walkers] = y[walkers]
        elif rand == 2:
            y[walkers] = y[walkers] - 1
            x[walkers] = x[walkers] + A
        else:
            x[walkers] = x[walkers] - 1 + A
            y[walkers] = y[walkers]
 
plt.scatter(x, y)
plt.grid()
plt.show()

# %%
# defining the number of walkers
w = 1000
# defining the number of steps
s = 10

A = .1
 
#creating two array for containing x and y coordinate
#of size equals to the number of walkers and filled up with 0's
x = np.zeros(w)
y = np.zeros(w)

for walkers in range(w):
    for steps in range(s):
        rand = randint(0,3)
        if rand == 0:
            y[walkers] = y[walkers] + 1
            x[walkers] = x[walkers] + A
        elif rand == 1:
            x[walkers] = x[walkers] + 1 + A
            y[walkers] = y[walkers]
        elif rand == 2:
            y[walkers] = y[walkers] - 1
            x[walkers] = x[walkers] + A
        else:
            x[walkers] = x[walkers] - 1 + A
            y[walkers] = y[walkers]
 
plt.scatter(x, y)
plt.grid()
plt.show()

# %%
# defining the number of walkers
w = 1000
# defining the number of steps
s = 10

A = .01
 
#creating two array for containing x and y coordinate
#of size equals to the number of walkers and filled up with 0's
x = np.zeros(w)
y = np.zeros(w)

for walkers in range(w):
    for steps in range(s):
        rand = randint(0,3)
        if rand == 0:
            y[walkers] = y[walkers] + 1
            x[walkers] = x[walkers] + A
        elif rand == 1:
            x[walkers] = x[walkers] + 1 + A
            y[walkers] = y[walkers]
        elif rand == 2:
            y[walkers] = y[walkers] - 1
            x[walkers] = x[walkers] + A
        else:
            x[walkers] = x[walkers] - 1 + A
            y[walkers] = y[walkers]
 
plt.scatter(x, y)
plt.grid()
plt.show()

# %% [markdown]
# ## 1,000 Walkers, 100 Steps

# %%
# defining the number of walkers
w = 1000
# defining the number of steps
s = 100
 
#creating two array for containing x and y coordinate
#of size equals to the number of walkers and filled up with 0's
x = np.zeros(w)
y = np.zeros(w)

for walkers in range(w):
    for steps in range(s):
        rand = randint(0,3)
        if rand == 0:
            y[walkers] = y[walkers] + 1
            x[walkers] = x[walkers]
        elif rand == 1:
            x[walkers] = x[walkers] + 1
            y[walkers] = y[walkers]
        elif rand == 2:
            y[walkers] = y[walkers] - 1
            x[walkers] = x[walkers]
        else:
            x[walkers] = x[walkers] - 1
            y[walkers] = y[walkers]
 
plt.scatter(x, y)
plt.grid()
plt.show()

# %% [markdown]
# ## 1,000 Walkers, 10 Steps + Weight (A)

# %%
# defining the number of walkers
w = 1000
# defining the number of steps
s = 100

A = .5

#creating two array for containing x and y coordinate
#of size equals to the number of walkers and filled up with 0's
x = np.zeros(w)
y = np.zeros(w)

for walkers in range(w):
    for steps in range(s):
        rand = randint(0,3)
        if rand == 0:
            y[walkers] = y[walkers] + 1
            x[walkers] = x[walkers] + A
        elif rand == 1:
            x[walkers] = x[walkers] + 1 + A
            y[walkers] = y[walkers]
        elif rand == 2:
            y[walkers] = y[walkers] - 1
            x[walkers] = x[walkers] + A
        else:
            x[walkers] = x[walkers] - 1 + A
            y[walkers] = y[walkers]
 
plt.scatter(x, y)
plt.grid()
plt.show()

# %%
# defining the number of walkers
w = 1000
# defining the number of steps
s = 100

A = .1

#creating two array for containing x and y coordinate
#of size equals to the number of walkers and filled up with 0's
x = np.zeros(w)
y = np.zeros(w)

for walkers in range(w):
    for steps in range(s):
        rand = randint(0,3)
        if rand == 0:
            y[walkers] = y[walkers] + 1
            x[walkers] = x[walkers] + A
        elif rand == 1:
            x[walkers] = x[walkers] + 1 + A
            y[walkers] = y[walkers]
        elif rand == 2:
            y[walkers] = y[walkers] - 1
            x[walkers] = x[walkers] + A
        else:
            x[walkers] = x[walkers] - 1 + A
            y[walkers] = y[walkers]
 
plt.scatter(x, y)
plt.grid()
plt.show()

# %%
# defining the number of walkers
w = 1000
# defining the number of steps
s = 100

A = .01

#creating two array for containing x and y coordinate
#of size equals to the number of walkers and filled up with 0's
x = np.zeros(w)
y = np.zeros(w)

for walkers in range(w):
    for steps in range(s):
        rand = randint(0,3)
        if rand == 0:
            y[walkers] = y[walkers] + 1
            x[walkers] = x[walkers] + A
        elif rand == 1:
            x[walkers] = x[walkers] + 1 + A
            y[walkers] = y[walkers]
        elif rand == 2:
            y[walkers] = y[walkers] - 1
            x[walkers] = x[walkers] + A
        else:
            x[walkers] = x[walkers] - 1 + A
            y[walkers] = y[walkers]
 
plt.scatter(x, y)
plt.grid()
plt.show()

# %% [markdown]
# ## 1,000 Walkers, 1,000 Steps

# %%
# defining the number of walkers
w = 1000
# defining the number of steps
s = 1000
 
#creating two array for containing x and y coordinate
#of size equals to the number of walkers and filled up with 0's
x = np.zeros(w)
y = np.zeros(w)

for walkers in range(w):
    for steps in range(s):
        rand = randint(0,3)
        if rand == 0:
            y[walkers] = y[walkers] + 1
            x[walkers] = x[walkers]
        elif rand == 1:
            x[walkers] = x[walkers] + 1
            y[walkers] = y[walkers]
        elif rand == 2:
            y[walkers] = y[walkers] - 1
            x[walkers] = x[walkers]
        else:
            x[walkers] = x[walkers] - 1
            y[walkers] = y[walkers]
 
plt.scatter(x, y)
plt.grid()
plt.show()

# %% [markdown]
# ## 1,000 Walkers, 1,000 Steps + Weight (A)

# %%
# defining the number of walkers
w = 1000
# defining the number of steps
s = 1000

A = .5

#creating two array for containing x and y coordinate
#of size equals to the number of walkers and filled up with 0's
x = np.zeros(w)
y = np.zeros(w)

for walkers in range(w):
    for steps in range(s):
        rand = randint(0,3)
        if rand == 0:
            y[walkers] = y[walkers] + 1
            x[walkers] = x[walkers] + A
        elif rand == 1:
            x[walkers] = x[walkers] + 1 + A
            y[walkers] = y[walkers]
        elif rand == 2:
            y[walkers] = y[walkers] - 1
            x[walkers] = x[walkers] + A
        else:
            x[walkers] = x[walkers] - 1 + A
            y[walkers] = y[walkers]
 
plt.scatter(x, y)
plt.grid()
plt.show()

# %%
# defining the number of walkers
w = 1000
# defining the number of steps
s = 1000

A = .1

#creating two array for containing x and y coordinate
#of size equals to the number of walkers and filled up with 0's
x = np.zeros(w)
y = np.zeros(w)

for walkers in range(w):
    for steps in range(s):
        rand = randint(0,3)
        if rand == 0:
            y[walkers] = y[walkers] + 1
            x[walkers] = x[walkers] + A
        elif rand == 1:
            x[walkers] = x[walkers] + 1 + A
            y[walkers] = y[walkers]
        elif rand == 2:
            y[walkers] = y[walkers] - 1
            x[walkers] = x[walkers] + A
        else:
            x[walkers] = x[walkers] - 1 + A
            y[walkers] = y[walkers]
 
plt.scatter(x, y)
plt.grid()
plt.show()

# %%
# defining the number of walkers
w = 1000
# defining the number of steps
s = 1000

A = .01

#creating two array for containing x and y coordinate
#of size equals to the number of walkers and filled up with 0's
x = np.zeros(w)
y = np.zeros(w)

for walkers in range(w):
    for steps in range(s):
        rand = randint(0,3)
        if rand == 0:
            y[walkers] = y[walkers] + 1
            x[walkers] = x[walkers] + A
        elif rand == 1:
            x[walkers] = x[walkers] + 1 + A
            y[walkers] = y[walkers]
        elif rand == 2:
            y[walkers] = y[walkers] - 1
            x[walkers] = x[walkers] + A
        else:
            x[walkers] = x[walkers] - 1 + A
            y[walkers] = y[walkers]
 
plt.scatter(x, y)
plt.grid()
plt.show()

# %% [markdown]
# ## 1,000 Walkers, 10,000 Steps

# %%
# defining the number of walkers
w = 1000
# defining the number of steps
s = 10000
 
#creating two array for containing x and y coordinate
#of size equals to the number of walkers and filled up with 0's
x = np.zeros(w)
y = np.zeros(w)

for walkers in range(w):
    for steps in range(s):
        rand = randint(0,3)
        if rand == 0:
            y[walkers] = y[walkers] + 1
            x[walkers] = x[walkers]
        elif rand == 1:
            x[walkers] = x[walkers] + 1
            y[walkers] = y[walkers]
        elif rand == 2:
            y[walkers] = y[walkers] - 1
            x[walkers] = x[walkers]
        else:
            x[walkers] = x[walkers] - 1
            y[walkers] = y[walkers]
 
plt.scatter(x, y)
plt.grid()
plt.show()

# %% [markdown]
# ## 1,000 Walkers, 10,000 Steps

# %%
# defining the number of walkers
w = 1000
# defining the number of steps
s = 10000

A  = .5

#creating two array for containing x and y coordinate
#of size equals to the number of walkers and filled up with 0's
x = np.zeros(w)
y = np.zeros(w)

for walkers in range(w):
    for steps in range(s):
        rand = randint(0,3)
        if rand == 0:
            y[walkers] = y[walkers] + 1
            x[walkers] = x[walkers] + A
        elif rand == 1:
            x[walkers] = x[walkers] + 1 + A
            y[walkers] = y[walkers]
        elif rand == 2:
            y[walkers] = y[walkers] - 1
            x[walkers] = x[walkers] + A
        else:
            x[walkers] = x[walkers] - 1 + A
            y[walkers] = y[walkers]
 
plt.scatter(x, y)
plt.grid()
plt.show()

# %%
# defining the number of walkers
w = 1000
# defining the number of steps
s = 10000

A  = .1

#creating two array for containing x and y coordinate
#of size equals to the number of walkers and filled up with 0's
x = np.zeros(w)
y = np.zeros(w)

for walkers in range(w):
    for steps in range(s):
        rand = randint(0,3)
        if rand == 0:
            y[walkers] = y[walkers] + 1
            x[walkers] = x[walkers] + A
        elif rand == 1:
            x[walkers] = x[walkers] + 1 + A
            y[walkers] = y[walkers]
        elif rand == 2:
            y[walkers] = y[walkers] - 1
            x[walkers] = x[walkers] + A
        else:
            x[walkers] = x[walkers] - 1 + A
            y[walkers] = y[walkers]
 
plt.scatter(x, y)
plt.grid()
plt.show()

# %%
# defining the number of walkers
w = 1000
# defining the number of steps
s = 10000

A  = .01

#creating two array for containing x and y coordinate
#of size equals to the number of walkers and filled up with 0's
x = np.zeros(w)
y = np.zeros(w)

for walkers in range(w):
    for steps in range(s):
        rand = randint(0,3)
        if rand == 0:
            y[walkers] = y[walkers] + 1
            x[walkers] = x[walkers] + A
        elif rand == 1:
            x[walkers] = x[walkers] + 1 + A
            y[walkers] = y[walkers]
        elif rand == 2:
            y[walkers] = y[walkers] - 1
            x[walkers] = x[walkers] + A
        else:
            x[walkers] = x[walkers] - 1 + A
            y[walkers] = y[walkers]
 
plt.scatter(x, y)
plt.grid()
plt.show()

# %%
xyzip = list(zip(x_array, y_array))

print(xyzip)
# Out:
# [(0, 0), (-66, -102), (-60, -68), (90, -10), (118, -52), (99, 15), (71, 17), (108, -12), (180, -32), (192, 60), (202, 110), (145, 163), (167, 77), (221, 85), (323, 173), (496, 40), (413, 163), (314, 38), (361, 119), (378, 74), (247, 41), (183, 23), (75, -75), (266, 10), (226, -66), (243, -91), (260, -130), (284, -134), (211, -241), (252, -308), (250, -290), (257, -201), (328, -180), (400, -226), (388, -212), (295, -249), (307, -289), (258, -162), (319, -187), (294, -234), (302, -146), (393, -241), (395, -325), (367, -299), (404, -300), (384, -200), (274, -188), (225, -229), (198, -270), (73, -331), (-93, -321), (-163, -267), (-246, -236), (-322, -202), (-187, -215), (-172, -306), (-84, -268), (-124, -240), (13, -379), (15, -425), (-12, -376), (122, -376), (101, -477), (188, -468), (159, -413), (304, -464), (388, -458), (375, -465), (350, -414), (431, -395), (383, -363), (377, -377), (312, -200), (332, -188), (365, -277), (421, -257), (489, -215), (567, -299), (501, -355), (613, -331), (620, -308), (584, -342), (690, -414), (670, -288), (743, -257), (664, -250), (760, -280), (803, -239), (664, -240), (677, -257), (615, -265), (704, -336), (698, -258), (642, -302), (517, -167), (496, -236), (573, -257), (520, -180), (585, -183), (585, -147), (430, -170), (488, -208), (504, -212), (626, -188), (533, -241), (374, -194), (516, -94), (527, -1), (543, -53), (528, -52), (542, -12), (546, 72), (519, 73), (478, 180), (513, 33), (516, 52), (602, 150), (600, 226), (530, 262), (505, 251), (568, 254), (561, 379), (586, 340), (541, 273), (496, 280), (370, 208), (385, 195), (366, 110), (493, 123), (464, 220), (471, 327), (451, 317), (578, 176), (689, 241), (594, 304), (545, 315), (563, 339), (431, 363), (429, 389), (382, 362), (366, 208), (354, 114), (418, 132),


# %%
probability_model = tf.keras.Sequential([
  model,
  tf.keras.layers.Softmax()
])

# %%
probability_model(x_test[:5])
# Out:
# <tf.Tensor: shape=(5, 10), dtype=float32, numpy=
# array([[1.35310998e-07, 1.93395593e-08, 2.88444835e-06, 2.44037510e-04,
#         8.68042929e-11, 9.65036520e-07, 4.86704904e-12, 9.99733984e-01,
#         6.44724014e-06, 1.15489893e-05],
#        [4.31333946e-09, 1.22206866e-05, 9.99963164e-01, 2.38359571e-05,
#         3.95536858e-15, 3.31532789e-07, 4.23439218e-07, 1.20380886e-12,
#         4.32626912e-08, 1.28323011e-13],
#        [1.29085294e-07, 9.99194920e-01, 1.69448584e-04, 7.06234787e-05,
#         4.55394947e-05, 4.98871350e-06, 6.04721936e-05, 3.15187703e-04,
#         1.38160161e-04, 5.09389110e-07],
#        [9.99909997e-01, 6.91897650e-09, 2.10701764e-05, 1.99918645e-07,
#         5.80181307e-08, 1.12091550e-06, 1.56570404e-05, 1.01897958e-05,
#         2.46545309e-08, 4.17301380e-05],
#        [1.01179730e-05, 3.99922678e-10, 5.21174697e-05, 3.76985057e-08,
#         9.88905549e-01, 2.94906869e-07, 5.04295804e-06, 4.85533055e-05,
#         2.74105832e-06, 1.09755015e-02]], dtype=float32)>

# %% [markdown]
# ## [Basic classification: Classify images of clothing](https://www.tensorflow.org/tutorials/keras/classification)

# %%
# TensorFlow and tf.keras
import tensorflow as tf

# Helper libraries
import numpy as np
import matplotlib.pyplot as plt

print(tf.__version__)
# Out:
# 2.7.0

# %%
fashion_mnist = tf.keras.datasets.fashion_mnist

(train_images, train_labels), (test_images, test_labels) = fashion_mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-labels-idx1-ubyte.gz
# 32768/29515 [=================================] - 0s 0us/step
# 40960/29515 [=========================================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-images-idx3-ubyte.gz
# 26427392/26421880 [==============================] - 0s 0us/step
# 26435584/26421880 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-labels-idx1-ubyte.gz
# 16384/5148 [===============================================================================================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-images-idx3-ubyte.gz
# 4423680/4422102 [==============================] - 0s 0us/step
# 4431872/4422102 [==============================] - 0s 0us/step

# %%
print("Classes: \n \
        1. T-shirt/top \n \
        2. Trouser \n \
        3. Pullover \n \
        4. Dress \n \
        5. Coat \n \
        6. Sandal \n \
        7. Shirt \n \
        8. Sneaker \n \
        9. Bag \n \
        10. Ankle boot")
# Out:
# Classes:
#          0. T-shirt/top
#          1. Trouser
#          2. Pullover
#          3. Dress
#          4. Coat
#          5. Sandal
#          6. Shirt
#          7. Sneaker
#          8. Bag
#          9. Ankle boot

# %%
class_names = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat',
               'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']

# %%
train_images.shape
# Out:
# (60000, 28, 28)

# %%
len(train_labels)
# Out:
# 60000

# %%
train_labels
# Out:
# array([9, 0, 0, ..., 3, 0, 5], dtype=uint8)

# %%
test_images.shape
# Out:
# (10000, 28, 28)

# %%
len(test_labels)
# Out:
# 10000

# %%
plt.figure()
plt.imshow(train_images[0])
plt.colorbar()
plt.grid(False)
plt.show()

# %%
train_images = train_images / 255.0

test_images = test_images / 255.0

# %%
plt.figure(figsize=(10,10))
for i in range(25):
    plt.subplot(5,5,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(train_images[i], cmap=plt.cm.binary)
    plt.xlabel(class_names[train_labels[i]])
plt.show()

# %%
model = tf.keras.Sequential([
    tf.keras.layers.Flatten(input_shape=(28, 28)),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dense(10)
])

# %%
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
model.fit(train_images, train_labels, epochs=10)
# Out:
# Epoch 1/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.5010 - accuracy: 0.8250
# Epoch 2/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.3784 - accuracy: 0.8634
# Epoch 3/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.3397 - accuracy: 0.8762
# Epoch 4/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.3144 - accuracy: 0.8830
# Epoch 5/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.2966 - accuracy: 0.8903
# Epoch 6/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.2831 - accuracy: 0.8955
# Epoch 7/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.2720 - accuracy: 0.8976
# Epoch 8/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.2595 - accuracy: 0.9030
# Epoch 9/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.2497 - accuracy: 0.9061
# Epoch 10/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.2425 - accuracy: 0.9094

# %%
test_loss, test_acc = model.evaluate(test_images,  test_labels, verbose=2)

print('\nTest accuracy:', test_acc)
# Out:
# 313/313 - 1s - loss: 0.3395 - accuracy: 0.8760 - 642ms/epoch - 2ms/step
#
# Test accuracy: 0.8759999871253967

# %%
probability_model = tf.keras.Sequential([model, 
                                         tf.keras.layers.Softmax()])

# %%
predictions = probability_model.predict(test_images)

# %%
predictions[0]
# Out:
# array([9.07576180e-07, 4.74130908e-11, 4.46288319e-11, 7.15465909e-09,
#        1.06200035e-08, 5.53552015e-03, 1.74498254e-07, 4.32732031e-02,
#        1.10844928e-06, 9.51188982e-01], dtype=float32)

# %%
np.argmax(predictions[0])
# Out:
# 9

# %%
test_labels[0]
# Out:
# 9

# %%
def plot_image(i, predictions_array, true_label, img):
  true_label, img = true_label[i], img[i]
  plt.grid(False)
  plt.xticks([])
  plt.yticks([])

  plt.imshow(img, cmap=plt.cm.binary)

  predicted_label = np.argmax(predictions_array)
  if predicted_label == true_label:
    color = 'blue'
  else:
    color = 'red'

  plt.xlabel("{} {:2.0f}% ({})".format(class_names[predicted_label],
                                100*np.max(predictions_array),
                                class_names[true_label]),
                                color=color)

def plot_value_array(i, predictions_array, true_label):
  true_label = true_label[i]
  plt.grid(False)
  plt.xticks(range(10))
  plt.yticks([])
  thisplot = plt.bar(range(10), predictions_array, color="#777777")
  plt.ylim([0, 1])
  predicted_label = np.argmax(predictions_array)

  thisplot[predicted_label].set_color('red')
  thisplot[true_label].set_color('blue')

# %%
i = 0
plt.figure(figsize=(6,3))
plt.subplot(1,2,1)
plot_image(i, predictions[i], test_labels, test_images)
plt.subplot(1,2,2)
plot_value_array(i, predictions[i],  test_labels)
plt.show()

# %%
i = 12
plt.figure(figsize=(6,3))
plt.subplot(1,2,1)
plot_image(i, predictions[i], test_labels, test_images)
plt.subplot(1,2,2)
plot_value_array(i, predictions[i],  test_labels)
plt.show()

# %%
# Plot the first X test images, their predicted labels, and the true labels.
# Color correct predictions in blue and incorrect predictions in red.
num_rows = 5
num_cols = 3
num_images = num_rows*num_cols
plt.figure(figsize=(2*2*num_cols, 2*num_rows))
for i in range(num_images):
  plt.subplot(num_rows, 2*num_cols, 2*i+1)
  plot_image(i, predictions[i], test_labels, test_images)
  plt.subplot(num_rows, 2*num_cols, 2*i+2)
  plot_value_array(i, predictions[i], test_labels)
plt.tight_layout()
plt.show()

# %%
# Grab an image from the test dataset.
img = test_images[1]

print(img.shape)
# Out:
# (28, 28)

# %%
# Add the image to a batch where it's the only member.
img = (np.expand_dims(img,0))

print(img.shape)
# Out:
# (1, 28, 28)

# %%
predictions_single = probability_model.predict(img)

print(predictions_single)
# Out:
# [[2.1323527e-03 2.3708511e-12 9.9531943e-01 6.0445171e-10 2.0166927e-03
#   6.2211304e-12 5.3152617e-04 1.1726190e-18 2.7432401e-09 4.4584833e-15]]

# %%
plot_value_array(1, predictions_single[0], test_labels)
_ = plt.xticks(range(10), class_names, rotation=45)
plt.show()

# %%
np.argmax(predictions_single[0])
# Out:
# 2

# %% [markdown]
# ## Prediction Mistakes Using Confusion Matrix

# %%
model = tf.keras.models.Sequential()

model.add(tf.keras.layers.Flatten(input_shape=(28, 28, 1)))

model.add(tf.keras.layers.Dense(units=128,
                       activation='relu'))

model.add(tf.keras.layers.Dense(units=10,
                       activation=None))

# %%
model.compile(loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              optimizer=tf.keras.optimizers.Adam(),
              metrics=['accuracy'])

# %%
history =  model.fit(train_images, train_labels, epochs=10)
# Out:
# Epoch 1/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.5010 - accuracy: 0.8238
# Epoch 2/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.3736 - accuracy: 0.8646
# Epoch 3/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.3351 - accuracy: 0.8782
# Epoch 4/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.3105 - accuracy: 0.8861
# Epoch 5/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.2924 - accuracy: 0.8919
# Epoch 6/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.2788 - accuracy: 0.8966
# Epoch 7/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.2684 - accuracy: 0.8995
# Epoch 8/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.2558 - accuracy: 0.9050
# Epoch 9/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.2477 - accuracy: 0.9073
# Epoch 10/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.2370 - accuracy: 0.9112

# %%
# Evaluate the model
plt.plot(history.history['accuracy'], label='accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.ylim([0.5, 1])
plt.legend(loc='lower right')

# %%
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report

# %%
 7, 3, 8, 1, 1, 9, 8, 1, 3, 3, 7, 5, 1, 5, 7, 8, 9, 6, 3, 5, 8, 4, 6, 3, 8, 6, 5, 5, 2, 7, 1, 9, 3, 5, 4, 8, 6, 2, 1, 1, 7, 9, 2, 2, 7, 0, 4, 8, 2, 2, 0, 6, 4, 4, 9, 6, 8, 4, 5, 9, 6, 3, 9, 4, 9, 8, 7, 4, 2, 2, 5, 3, 7, 6, 7, 2, 9, 3, 7, 6, 9, 3, 8, 4, 4, 7, 2, 4, 6, 2, 0, 7, 8, 4, 2, 4, 5, 5, 6, 4, 5, 5, 8, 1, 1, 7, 4, 6, 9, 6, 8, 7, 2, 6, 1, 2, 7, 7, 6, 9, 8, 5, 1, 1, 0, 2, 0, 9, 0, 1, 9, 0, 5, 5, 2, 0, 7, 0, 2, 6, 1, 3, 1, 3, 2, 7, 2, 4, 9, 5, 2, 9, 6, 3, 4, 4, 6, 6, 5, 2, 2, 5, 6, 1, 4, 2, 5, 4, 4, 8, 0, 2, 4, 0, 6, 3, 6, 8, 3, 8, 2, 0, 4, 4, 8, 8, 4, 5, 2, 2, 3, 0, 1, 9, 0, 9, 1, 9, 6, 5, 2, 4, 7, 3, 8, 5, 6, 8, 0, 7, 5, 5, 9, 5, 0, 0, 0, 3, 2, 4, 4, 5, 7, 1, 3, 4, 6, 6, 5, 1, 6, 7, 3, 4, 8, 8, 4, 8, 9, 4, 1, 6, 5, 2, 7, 8, 5, 6, 8, 5, 2, 2, 8, 9,  ...

# %%
print("Classes: \n \
        1. T-shirt/top \n \
        2. Trouser \n \
        3. Pullover \n \
        4. Dress \n \
        5. Coat \n \
        6. Sandal \n \
        7. Shirt \n \
        8. Sneaker \n \
        9. Bag \n \
        10. Ankle boot")
# Out:
# Classes:
#          1. T-shirt/top
#          2. Trouser
#          3. Pullover
#          4. Dress
#          5. Coat
#          6. Sandal
#          7. Shirt
#          8. Sneaker
#          9. Bag
#          10. Ankle boot

# %%
mat = confusion_matrix(test_labels, test_labels_pred)
print(mat)
# Out:
# [[813   1  16  19   6   1 141   0   3   0]
#  [  1 977   0  16   3   0   3   0   0   0]
#  [ 20   1 808  10 112   0  49   0   0   0]
#  [ 19   8  11 889  33   0  37   0   3   0]
#  [  1   0  97  39 819   0  44   0   0   0]
#  [  0   0   0   1   0 936   0  40   1  22]
#  [106   2 118  24 107   0 641   0   2   0]
#  [  0   0   0   0   0   5   0 968   1  26]
#  [ 11   2   7   7   5   1  11   5 951   0]
#  [  0   0   0   0   0   3   1  34   0 962]]

# %%
import seaborn as sns
from sklearn.svm import SVC

# %%
sns.heatmap(confusion_matrix(test_labels, test_labels_pred), annot = True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-8cf53e7dacb2> in <module>()
# ----> 1 sns.heatmap(confusion_matrix(test_labels, test_labels_pred), annot = True)
#
# NameError: name 'confusion_matrix' is not defined

# %%
print("According to the confusion matrix, the most mistakes are made in Row 1, Column 7 \
       (Mistaking T-Shirt/Top for Shirt 141 Times")
